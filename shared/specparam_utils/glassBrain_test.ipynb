# %%
from glassBrain import *

# %%
results = plot_dipoles_glass_brain('../results/IC_clusters/pruned_clusters/Cls_4_prune.csv', '../demographicsPsych/data/tidy/exergame_tidy.csv','../results/specparam/clusterMapping/')
# Out:
# Loaded medication data for 67 participants
# Medication types found: {'methylphenidate', 'amphetamine', 'none', 'other'}
# Loaded 41 valid dipole coordinates from 41 total rows
# Medication type distribution:
#   amphetamine: 15
#   none: 11
#   methylphenidate: 11
#   other: 4
# Successfully loaded 41 coordinates
#
# === Validating Dipole Coordinates ===
# Coordinate Validation Results:
# - Total coordinates: 41
# - Valid coordinates: 41
#
# Average MNI coordinate: [-35.05, -71.68, 14.70]
#
# === Mapping Average Coordinate to AAL3 Atlas ===
# [get_dataset_dir] Dataset found in C:\Users\ntasnim\nilearn_data\aal_3v2
# Using AAL3 version 3v2 with 166 regions
# Atlas voxel size: [2. 2. 2.] mm (average: 2.00 mm)
# Best match: Occipital_Inf_L
# Confidence: exact_match
# Plotted 11 dipoles for methylphenidate medication type
# Plotted 15 dipoles for amphetamine medication type
# Plotted 11 dipoles for none medication type
# Plotted 4 dipoles for other medication type
#
# ...
