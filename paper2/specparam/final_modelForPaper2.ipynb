# %% [markdown]
# # Final Model for Paper 2
#
# ## UPDATED Analysis Plan
# Throughout the notebook, we complete the following tasks:
# 1. Fit group spectra
# 2. Create a .csv export for the following metrics:
#     - All peak metrics (4 columns: cfs, pws, bws, model index)
#         - Make sure you assign frequency bands based off of cfs value
#     - All Model Metrics
#         - Aperiodic parameters (2 columns: offsets, exps [in order models])
#         - Errors
#         - R-squared
#     - **Make sure you use the model index to pull relevant information from `df_final`**
# 3. Plot mean spectra with standard deviation for all 11 clusters. (although we will only be using a select few).
#     - Plot with aperiodic fit as dotted line (just for record keeping)
#     - Plot as flattened spectrum
#         - For these spectra, we will need to plot all participants averaged. However, we will create the following splits:
#                 - Baseline
#                 - All Executive Function
#                 - Shoulder Spectra averaged and Tandem Spectra Average (all participants should have data from all trials)

# %%
# Spectral parameterization imports
from specparam import SpectralGroupModel

# Import custom function
from create_specparam_plots import *

# %% [markdown]
# ### Load Datasets

# %%
df = pd.read_pickle('E:/Tasnim_Dissertation_Analysis/specparam_analysis/Paper 2/sedentary/results/Paper2_Sedentary_df_final.pkl')

# %% [markdown]
# ### Fit Spectra

# %%
# Extract spectra from final dataframe
spectra = np.array([spec for spec in df['spectra']])
freqs = np.arange(251)
# Initialize and fit new SpectralGroupModel on cleaned data
fg = SpectralGroupModel(peak_width_limits=[2, 8], min_peak_height=0.2, peak_threshold=2,
                               max_n_peaks=6, verbose=False)
freq_range = [1, 55]
fg.fit(freqs, spectra, freq_range)
fg.print_results()
fg.save_report('E:/Tasnim_Dissertation_Analysis/specparam_analysis/Paper 2/sedentary/results/final_model/final_sedentary_groupModel_for_Paper2.pdf')
# Out:
# ==================================================================================================
#
#                                           GROUP RESULTS
#
#                            Number of power spectra in the Group: 11394
#
#                         The model was run on the frequency range 1 - 55 Hz
#                                  Frequency Resolution is 1.00 Hz
#
#                               Power spectra were fit without a knee.
#
#                                       Aperiodic Fit Values:
#                         Exponents - Min:  0.029, Max:  2.117, Mean: 0.934
#
#                         In total 19491 peaks were extracted from the group
#
#                                      Goodness of fit metrics:
#                             R2s -  Min:  0.575, Max:  0.998, Mean: 0.954
#                          Errors -  Min:  0.014, Max:  0.103, Mean: 0.049
#
# ==================================================================================================

# %% [markdown]
# ### Export Summary Data as .csv files
# They will be analyzed further to summarize our data for the manuscript

# %% [markdown]
# #### Extracting Parameters

# %%
# Extract peak parameters
peaks = fg.get_params('peak_params')  # 4 columns: cfs, pws, bws, model index
aps = fg.get_params('aperiodic_params')  # 2 columns: offsets, exps [in order of channels/models]
# Extract goodness-of-fit metrics
errors = fg.get_params('error')
r2s = fg.get_params('r_squared')

# %% [markdown]
# ##### Peaks Export
# For each peak that we export, we will need to export its model's following values from `df`:
# 1. subject
# 2. session
# 3. experience
# 4. component
# 5. cluster

# %%
peaks_export = pd.DataFrame(peaks, columns=['cf', 'pw', 'bw', 'model_ind'])

# Convert Model Indices to integers to index from df and MERGE
peaks_export['model_ind'] = peaks_export['model_ind'].astype(int)
peaks_merged = peaks_export.merge(
    df[['subject', 'session', 'experience', 'component', 'cluster']],
    left_on='model_ind',
    right_index=True,
    how='left'
)
print("Method 1 - Using pandas merge:")
print(peaks_merged.head())

# Creating a column for frequency bands
def assign_freq_band(cf_value):
    if 1 <= cf_value < 4:
        return "delta"
    elif 4 <= cf_value < 8:
        return "theta"
    elif 8 <= cf_value < 12:
        return "alpha"
    elif 12 <= cf_value < 20:
        return "low_beta"
    elif 20 <= cf_value < 30:
        return "high_beta"
    elif 30 <= cf_value < 55:
        return "gamma"
    else:
        return None  # Default if cf doesn't fall within the specified ranges
peaks_merged['freq_band'] = peaks_merged['cf'].apply(assign_freq_band)

# Save as .csv file for analysis on R
peaks_merged.to_csv('E:/Tasnim_Dissertation_Analysis/specparam_analysis/Paper 2/sedentary/results/final_model/peaks.csv', index=False)
# Out:
# Method 1 - Using pandas merge:
#           cf        pw        bw  model_ind  subject session     experience  \
# 0  20.112993  0.370184  6.418041          0  exgm002      s1  digitbackward
# 1   9.716587  0.447956  2.000000          1  exgm002      s1   digitforward
# 2  19.344531  0.490005  7.180311          1  exgm002      s1   digitforward
# 3  10.083585  0.596981  3.106627          2  exgm002      s1         gonogo
# 4  19.286391  0.577909  8.000000          2  exgm002      s1         gonogo
#
#    component  cluster
# 0          9       10
# 1          9       10
# 2          9       10
# 3          9       10
# 4          9       10

# %% [markdown]
# ##### Model Metrics Export
# Just like above we will need to export each model's following values from `df`:
# 1. subject
# 2. session
# 3. experience
# 4. component
# 5. cluster

# %%
# Ensure all arrays are 2D
r2s = r2s.reshape(-1, 1)  # Reshape r2s to (12, 1)
errors = errors.reshape(-1, 1)  # Reshape errors to (12, 1)

# Horizontally stack aperiodic params, R^2, and errors
model_metrics = pd.DataFrame(
    data=np.hstack([aps, r2s, errors]),  # Horizontally stack arrays
    columns=["offset", "exp", "r2", "error"]  # Column names
)

# Add Model Index for set up for joining with model information
model_metrics["model_ind"] = np.arange(len(df), dtype=int)

# Add Model Details to model_metric dataframe
model_metrics_merged = model_metrics.merge(
    df[['subject', 'session', 'experience', 'component', 'cluster']],
    left_on='model_ind',
    right_index=True,
    how='left'
)

# Write .csv to results folder
model_metrics_merged.to_csv('E:/Tasnim_Dissertation_Analysis/specparam_analysis/Paper 2/sedentary/results/final_model/model_metrics.csv', index=False)

# %% [markdown]
# ## Creating Plots for each cluster

# %%
create_all_plots(df, fg) # make sure you edit this function by the time you are analyzing two sessions!
# Out:
# Loading intervention assignments from ../demographicsPsych/data/intervention_assignments.xlsx...
# Loaded 63 intervention assignments
#
# Starting plot generation...
# Clusters: [np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12)]
# Interventions: ['Biking', 'Dance_Exergaming', 'Music_Listening']
#
# Cluster 3 - Peak y-limit: 9.88
#
# Processing Cluster 3, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 3, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 3, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 4 - Peak y-limit: 10.07
#
# Processing Cluster 4, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 4, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 4, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 5 - Peak y-limit: 7.09
#
# Processing Cluster 5, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 5, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 5, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 6 - Peak y-limit: 7.16
#
# Processing Cluster 6, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 6, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 6, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 7 - Peak y-limit: 10.51
#
# Processing Cluster 7, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 7, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 7, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 8 - Peak y-limit: 10.30
#
# Processing Cluster 8, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 8, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 8, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 9 - Peak y-limit: 4.54
#
# Processing Cluster 9, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 9, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 9, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 10 - Peak y-limit: 6.52
#
# Processing Cluster 10, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 10, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 10, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 11 - Peak y-limit: 9.99
#
# Processing Cluster 11, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 11, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 11, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# Cluster 12 - Peak y-limit: 10.06
#
# Processing Cluster 12, Intervention Biking:
#   Created baseline plots for Biking
#   Created gonogo_stroop plots for Biking
#   Created wcst_digit plots for Biking
#   Created shoulder plots for Biking
#   Created tandem plots for Biking
#
# Processing Cluster 12, Intervention Dance_Exergaming:
#   Created baseline plots for Dance_Exergaming
#   Created gonogo_stroop plots for Dance_Exergaming
#   Created wcst_digit plots for Dance_Exergaming
#   Created shoulder plots for Dance_Exergaming
#   Created tandem plots for Dance_Exergaming
#
# Processing Cluster 12, Intervention Music_Listening:
#   Created baseline plots for Music_Listening
#   Created gonogo_stroop plots for Music_Listening
#   Created wcst_digit plots for Music_Listening
#   Created shoulder plots for Music_Listening
#   Created tandem plots for Music_Listening
#
# ============================================================
#
# All plots have been created and saved!
# Output directory: E:/Tasnim_Dissertation_Analysis/specparam_analysis/Paper 2/sedentary/results/final_model/
